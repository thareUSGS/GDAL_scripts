# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

import numpy as np

from osgeo import gdal, osr
from gdalconst import *

# %%
mtopo = gdal.Open('megt90n000cb.lbl')


# one should firt get an array out
mtopoarray = np.array(mtopo.GetRasterBand(1).ReadAsArray())

# then we show the image
plt.imshow(mtopoarray)

cols = mtopo.RasterXSize 
rows = mtopo.RasterYSize
print("cols of mola is: ", cols)
print("rows of mola is: ", rows)
# Out:
# cols of mola is:  1440
# rows of mola is:  720

# %%
minmars = np.nanmin(mtopoarray)
maxmars = np.nanmax(mtopoarray)
print("min of mola is: ", minmars)
print("max of mola is: ", maxmars)

# histogram
binsmars = np.linspace(minmars, maxmars, 50)

histmars, binsmars = np.histogram(mtopoarray, binsmars)
plt.plot( histmars, binsmars[:-1] )
plt.show()
# Out:
# min of mola is:  -8068
# max of mola is:  21134

# %%
#try some bokeh plotting using numpy array
from bokeh.plotting import figure, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3de6d186-b4a3-4c80-90b7-d8daeced0371">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="MOLA", x_range=(0,360), y_range=(-90,90), plot_width=720, plot_height=360)
#needed to flip array for some reason (ud or up-down)
p.image(image=[np.flipud(mtopoarray)], x=0, y=-90, dw=360, dh=180, palette="Spectral11")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8f4f4707-14fd-4593-9642-8038b42cbdb8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8f4f4707-14fd-4593-9642-8038b42cbdb8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8f4f4707-14fd-4593-9642-8038b42cbdb8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8f4f4707-14fd-4593-9642-8038b42cbdb8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"967084b8-59b5-403d-9da6-a7d4728658b7":{"roots":{"references":[{"attributes":{"plot":{"id":"c2967eeb-b59d-4789-a7b6-5b58e3efc9da","subtype":"Figure","type":"Plot"}},"id":"87a9087c-12ff-4758-8c6a-fb4e40e5c9ea","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"int16","shape":[720,1440]}]}},"id":"6ea39433-378b-44ff-8c87-bad5e1966c3b","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"59499f75-9d46-46fd-9f10-a38ba8eb3614","type":"LinearAxis"}],"left":[{"id":"a275472e-8d37-458a-9b60-4cadbe73bcf2","type":"LinearAxis"}],"plot_height":360,"plot_width":720,"renderers":[{"id":"59499f75-9d46-46fd-9f10-a38ba8eb3614","type":"LinearAxis"},{"id":"f39bc5c9-6674-4042-a185-f0701abf98b5","type":"Grid"},{"id":"a275472e-8d37-458a-9b60-4cadbe73bcf2","type":"LinearAxis"},{"id":"f1335ed9-de2e-4d8f-9651-dc3eb97603af","type":"Grid"},{"id":"bb5a2ab1-4122-47e9-86d6-7363c2f5d79e","type":"BoxAnnotation"},{"id":"30eb98a2-c2f8-44c8-aa3b-2d38bdc6a767","type":"GlyphRenderer"}],"title":{"id":"2aee2c0b-8135-4a4e-8a5e-8d5b234f1bed","type":"Title"},"tool_events":{"id":"bdfa299c-aaee-482d-b4cc-ba58dfff926f","type":"ToolEvents"},"toolbar":{"id":"53455a1e-cd6a-4741-9904-eee3b82db87c","type":"Toolbar"},"x_range":{"id":"6812c911-bb51-4410-8c2a-1a27ff9ac498","type":"Range1d"},"y_range":{"id":"ee6f8210-2b31-4dd1-813c-56eda0858db9","type":"Range1d"}},"id":"c2967eeb-b59d-4789-a7b6-5b58e3efc9da","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"MOLA"},"id":"2aee2c0b-8135-4a4e-8a5e-8d5b234f1bed","type":"Title"},{"attributes":{},"id":"bdfa299c-aaee-482d-b4cc-ba58dfff926f","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7bfb0885-9631-4237-955f-6967a363d45c","type":"PanTool"},{"id":"e04693a5-84f0-42e7-b6c7-a9936f8522a2","type":"WheelZoomTool"},{"id":"103e5182-5dc9-4040-a884-bb9ad71e4c86","type":"BoxZoomTool"},{"id":"0c46b6f4-a9ad-41f0-a86a-ee3cb7f10bb5","type":"SaveTool"},{"id":"40c299d1-02df-4a03-ab97-5fb67c298a19","type":"ResetTool"},{"id":"87a9087c-12ff-4758-8c6a-fb4e40e5c9ea","type":"HelpTool"}]},"id":"53455a1e-cd6a-4741-9904-eee3b82db87c","type":"Toolbar"},{"attributes":{"callback":null,"end":360},"id":"6812c911-bb51-4410-8c2a-1a27ff9ac498","type":"Range1d"},{"attributes":{"data_source":{"id":"6ea39433-378b-44ff-8c87-bad5e1966c3b","type":"ColumnDataSource"},"glyph":{"id":"da6c00e9-503a-4c69-9532-29a1cd572f56","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"efb94e75-2061-4525-86cf-f011302c861d","type":"Image"},"selection_glyph":null},"id":"30eb98a2-c2f8-44c8-aa3b-2d38bdc6a767","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"d7d3d48c-cd0f-48ed-b23b-704774915765","type":"BasicTickFormatter"},"plot":{"id":"c2967eeb-b59d-4789-a7b6-5b58e3efc9da","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f910214-0c7f-402b-80fc-a9ed3e6c2d2f","type":"BasicTicker"}},"id":"59499f75-9d46-46fd-9f10-a38ba8eb3614","type":"LinearAxis"},{"attributes":{"callback":null,"end":90,"start":-90},"id":"ee6f8210-2b31-4dd1-813c-56eda0858db9","type":"Range1d"},{"attributes":{"color_mapper":{"id":"9e08fa4f-a78e-4f4f-9feb-9fe410b95919","type":"LinearColorMapper"},"dh":{"units":"data","value":180},"dw":{"units":"data","value":360},"image":{"field":"image"},"x":{"value":0},"y":{"value":-90}},"id":"efb94e75-2061-4525-86cf-f011302c861d","type":"Image"},{"attributes":{},"id":"3f910214-0c7f-402b-80fc-a9ed3e6c2d2f","type":"BasicTicker"},{"attributes":{"palette":["#5e4fa2","#3288bd","#66c2a5","#abdda4","#e6f598","#ffffbf","#fee08b","#fdae61","#f46d43","#d53e4f","#9e0142"]},"id":"8af850c4-9583-4d5b-a919-9d78c58d5466","type":"LinearColorMapper"},{"attributes":{"plot":{"id":"c2967eeb-b59d-4789-a7b6-5b58e3efc9da","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f910214-0c7f-402b-80fc-a9ed3e6c2d2f","type":"BasicTicker"}},"id":"f39bc5c9-6674-4042-a185-f0701abf98b5","type":"Grid"},{"attri ...

# %%
# test R
import rpy2
from rpy2.robjects.packages import importr
import rpy2.robjects as robjects

# %%
# from: https://sites.google.com/site/aslugsguidetopython/data-analysis/pandas/calling-r-from-python
robjects.r('x=c()')
robjects.r('x[1]=22')
robjects.r('x[2]=44')
print(robjects.r('x'))
type(robjects.r('x'))
# Out:
# [1] 22 44
# rpy2.robjects.vectors.FloatVector

# %%
#convert from numpy to R
from rpy2.robjects.numpy2ri import numpy2ri
rpy2.robjects.numpy2ri.activate()

#convert image array from numpy -- for testing conver left 8 columns only
rtopoarray = numpy2ri(mtopoarray[:,0:8])
type(rtopoarray)

#do something with R array - plots stats per image image column (sample)
print (robjects.r.summary(rtopoarray))
# Out:
#        V1              V2              V3              V4
#
#  Min.   :-5419   Min.   :-5336   Min.   :-4857   Min.   :-4895
#
#  1st Qu.:-3265   1st Qu.:-3260   1st Qu.:-3260   1st Qu.:-3260
#
#  Median :-1289   Median :-1240   Median :-1211   Median :-1182
#
#  Mean   :-1080   Mean   :-1061   Mean   :-1075   Mean   :-1081
#
#  3rd Qu.: 1379   3rd Qu.: 1399   3rd Qu.: 1393   3rd Qu.: 1334
#
#  Max.   : 4716   Max.   : 4710   Max.   : 4705   Max.   : 4704
#
#        V5              V6              V7              V8
#
#  Min.   :-4946   Min.   :-4970   Min.   :-4978   Min.   :-4978
#
#  1st Qu.:-3296   1st Qu.:-3318   1st Qu.:-3358   1st Qu.:-3337
#
#  Median :-1216   Median :-1166   Median :-1176   Median :-1160
#
#  Mean   :-1089   Mean   :-1094   Mean   :-1103   Mean   :-1101
#
#  3rd Qu.: 1308   3rd Qu.: 1282   3rd Qu.: 1240   3rd Qu.: 1246
#
#  Max.   : 4702   Max.   : 4699   Max.   : 4695   Max.   : 4691

# %%
#Try some R plotting using ggplot2 - not working

# %%
#Try some rbokeh plotting - not working
#rbokeh = importr('rbokeh')
